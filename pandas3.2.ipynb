# %%
! pip install pymysql
! pip install pandas
! pip install sqlalchemy
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sqlalchemy
import pandas as pd

logim_banco = 'toor'
senha_banco = '#Suporte%402025'
seervidor = '10.86.198.43'
porta = '3306'
banco = 'GUSTAVO'

# String de conexão com banco de dados 

conexao = sqlalchemy.create_engine(f'mysql+pymysql://{logim_banco}:{senha_banco}@{seervidor}:{porta}/{banco}', echo=True)
conexao2 = sqlalchemy.create_engine('sqlite:///teste.db')

# %%
df_olipici = pd.read_csv('athlete_events.csv', sep=',')
display(df_olipici)
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df_olipici.to_sql('athlete_events',con= conexao, if_exists= 'replace', index= False)
# Out:
# 2025-05-06 20:18:21,003 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-05-06 20:18:21,004 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-05-06 20:18:21,006 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-05-06 20:18:21,006 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-05-06 20:18:21,007 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-05-06 20:18:21,008 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-05-06 20:18:21,009 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-06 20:18:21,034 INFO sqlalchemy.engine.Engine DESCRIBE `gustavo`.`athlete_events`
# 2025-05-06 20:18:21,034 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-05-06 20:18:21,037 INFO sqlalchemy.engine.Engine
# CREATE TABLE athlete_events (
# 	`ID` BIGINT,
# 	`Name` TEXT,
# 	`Sex` TEXT,
# 	`Age` FLOAT(53),
# 	`Height` FLOAT(53),
# 	`Weight` FLOAT(53),
# 	`Team` TEXT,
# 	`NOC` TEXT,
# 	`Games` TEXT,
# 	`Year` BIGINT,
# 	`Season` TEXT,
# 	`City` TEXT,
# 	`Sport` TEXT,
# ...
